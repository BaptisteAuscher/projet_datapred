# %%
from eventregistry import *

er = EventRegistry(apiKey = "aba2d0bf-e9b5-4e66-bd94-37e747b764c8", allowUseOfArchive = False)

q = QueryArticlesIter(keywords = ["Barack Obama"], dataType = ["news", "pr"])
# we limit here the results to 100. If you want more, remove or increasae maxItems
for article in q.execQuery(er, sortBy="date", sortByAsc=False, maxItems=100):
    print(article)
# Out:
# {'uri': '8038167953', 'lang': 'eng', 'isDuplicate': False, 'date': '2024-03-20', 'time': '10:12:04', 'dateTime': '2024-03-20T10:12:04Z', 'dateTimePub': '2024-03-20T10:10:02Z', 'dataType': 'news', 'sim': 0.9137254953384399, 'url': 'https://www.ndtv.com/world-news/no-bidders-present-at-myanmar-auction-for-sale-of-suu-kyi-home-say-witness-media-5273484', 'title': "No Bidders For Auction Of Aung San Suu Kyi's Myanmar Home: Report", 'body': 'Nobel laureate Suu Kyi is serving 27 years in detention at an undisclosed location for a multitude of offences her supporters say are fabricated.\n\nNo bidders showed up on Wednesday at an auction in Myanmar for the sale of the home of jailed former leader Aung San Suu Kyi, for which the starting price had been set at around $90 million, a witness and local media reported.\n\nThe family property on Yangon\'s Inye Lake, measuring 1.923 acres (0.78 hectares) was up for auction at the behest of the Supreme Court after a years-long legal battle between Su
# ...
